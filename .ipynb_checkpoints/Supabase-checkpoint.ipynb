# %% [markdown]
# ## Cloud Storage (Supabase)

# %% [markdown]
# **Import dependencies**
#
# You may install the `supabase` library using the code below.
#
# ```bash
# # with pip
# pip install supabase
#
# # with conda
# conda install -c conda-forge supabase
# ```

# %%
import os
from supabase import create_client, Client
from dotenv import load_dotenv

import pandas as pd
import logging


logging.getLogger("httpx").setLevel(logging.WARNING)

# %% [markdown]
# Set your Supabase environment variables in a dotenv file, or using the shell:

# %%
load_dotenv()

url = os.environ.get("supabase_url")
key = os.environ.get("supabase_secret")

# Initialize client
supabase = create_client(url, key)

# %% [markdown]
# Use the supabase client to interact with your database.

# %%
table = supabase.table("mock_data")

# %% [markdown]
# Perform **CRUD operations** using the builtin methods from the `supabase` client.
#
# - Create
# - Read
# - Update
# - Delete

# %% [markdown]
# **Select Data**

# %%
dir(table)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__orig_class__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_is_protocol',
#  'delete',
#  'insert',
#  'path',
#  'select',
#  'session',
#  'update',
#  'upsert']

# %%
table.select('*').execute().data
# Out:
# [{'id': 1,
#   'first_name': 'Jerrome',
#   'last_name': 'Duffan',
#   'email': 'jduffan0@reverbnation.com',
#   'gender': 'Male',
#   'skill': 'Comic Book Illustration',
#   'race': 'Uruguayan'},
#  {'id': 2,
#   'first_name': 'Rosanna',
#   'last_name': 'Liepmann',
#   'email': 'rliepmann1@redcross.org',
#   'gender': 'Female',
#   'skill': 'Eagle PCB',
#   'race': 'Peruvian'},
#  {'id': 3,
#   'first_name': 'Aurea',
#   'last_name': 'Shoubridge',
#   'email': 'ashoubridge2@patch.com',
#   'gender': 'Female',
#   'skill': 'CPI',
#   'race': 'South American'},
#  {'id': 4,
#   'first_name': 'Gerick',
#   'last_name': 'Tilt',
#   'email': 'gtilt3@tinyurl.com',
#   'gender': 'Genderqueer',
#   'skill': 'XML Spy',
#   'race': 'Cherokee'},
#  {'id': 5,
#   'first_name': 'Peria',
#   'last_name': 'Le Pine',
#   'email': 'plepine4@imgur.com',
#   'gender': 'Female',
#   'skill': 'RRDTool',
#   'race': 'Comanche'},
#  {'id': 6,
#   'first_name': 'Cass',
#   'last_name': 'Gingles',
#   'email': 'cgingles5@reddit.com',
#   'gender': 'Female',
#   'skill': 'Athletics',
#   'race': 'Cuban'},
#  {'id': 7,
#   'first_name': 'Diannne',
#   'last_name': 'Huckabe',
#   'email': 'dhuckabe6@acquirethisname.com',
#   'gender': 'Female',
#   'skill': 'Shopping Centers',
#   'race': 'Argentinian'},
#  {'id': 8,
#   'first_name': 'Parke',
#   'last_name': 'Pargiter',
#   'email': 'ppargiter7@tripadvisor.com',
#   'gender': 'Male',
#   'skill': 'SRTP',
#   'race': 'Shoshone'},
#  {'id': 9,
#   'first_name': 'Corbin',
#   'last_name': 'La Croce',
#   'email': 'clacroce8@ebay.com',
#   'gender': 'Non-binary',
#   'skill': 'Xsigo',
#   'race': 'Hmong'},
#  {'id': 10,
#   'first_name': 'Elianora',
#   'last_name': 'Parmley',
#   'email': 'eparmley9@mediafire.com',
#   'gender': 'Female',
#   'skill': 'Natural Resource Management',
#   'race': 'Chamorro'},
#  {'id': 11,
#   'first_name': 'Gene',
#   'last_name': 'Gethen',
#   'email': 'ggethena@businessinsider.com',
#   'gender': 'Male',
#   'skill': 'Art Direction',
#   'race': 'American Indian'},
#  {'id': 12,
#   'first_name': 'Raynor',
#   'last_name': 'Saddler',
#   'email': 'rsaddlerb@tumblr.com',
#   'gender': 'Male',
#   'skill': 'IEX',
#   'race': 'Native Hawaiian and Other Pacific Islander (NHPI)'},
#  {'id': 13,
#   'first_name': 'Rebekah',
#   'last_name': 'Creech',
#   'email': 'rcreechc@umich.edu',
#   'gender': 'Female',
#   'skill': 'Urology',
#   'race': 'Tlingit-Haida'},
#  {'id': 14,
#   'first_name': 'Dill',
#   'last_name': 'Itzhayek',
#   'email': 'ditzhayekd@sbwire.com',
#   'gender': 'Male',
#   'skill': 'BMD',
#   'race': 'Latin American Indian'},
#  {'id': 15,
#   'first_name': 'Nolana',
#   'last_name': 'Renzo',
#   'email': 'nrenzoe@123-reg.co.uk',
#   'gender': 'Female',
#   'skill': 'Biochemistry',
#   'race': 'Spaniard'},
#  {'id': 16,
#   'first_name': 'Homer',
#   'last_name': 'Keates',
#   'email': 'hkeatesf@cornell.edu',
#   'gender': 'Male',
#   'skill': 'AODA',
#   'race': 'Menominee'},
#  {'id': 17,
#   'first_name': 'Sherman',
#   'last_name': 'Spensly',
#   'email': 'sspenslyg@house.gov',
#   'gender': 'Male',
#   'skill': 'NWDI',
#   'race': 'Apache'},
#  {'id': 18,
#   'first_name': 'Casandra',
#   'last_name': 'Galea',
#   'email': 'cgaleah@weather.com',
#   'gender': 'Female',
#   'skill': 'Database Design',
#   'race': 'Pakistani'},
#  {'id': 19,
#   'first_name': 'Madelene',
#   'last_name': 'Grinston',
#   'email': 'mgrinstoni@goodreads.com',
#   'gender': 'Female',
#   'skill': 'Lunch',
#   'race': 'Micronesian'},
#  {'id': 20,
#   'first_name': 'Anderson',
#   'last_name': 'Titterington',
#   'email': 'atitteringtonj@tamu.edu',
#   'gender': 'Male',
#   'skill': 'JMeter',
#   'race': 'Malaysian'},
#  {'id': 21,
#   'first_name': 'Herbie',
#   'last_name': 'Gellier',
#   'email': 'hgellierk@amazonaws.com',
#   'gender': 'Male',
#   'skill': 'JAXB',
#   'race': 'Ute'},
#  {'id': 22,
#   'first_name': 'Jo ann',
#   'last_name': 'Klehyn',
#   'email': 'jklehynl@google.co.jp',
#   'gender': 'Female',
#   'skill': 'Chi Nei Tsang',
#   'race': 'Comanche'},
#  {'id': 23,
#   'first_name': 'Sandie',
#   'last_name': 'Matkin',
#   'email': 'smatkinm@blogs.com',
#   'gender': 'Female',
#   'skill': 'Abaqus',
#   'race': 'Kiowa'},
#  {'id': 24,
#   'first_name': 'Clemence',
#   'last_name': 'Hannabuss',
#   'email': 'channabussn@bloomberg.com',
#   'gender': 'Female',
#   'skill': 'Ignite-UX',
#   'race': 'Cheyenne'},
#  {'id': 25,
#   'first_name': 'Fran',
#   'last_name': 'Dillaway',
#   'email': 'fdillawayo@nhs.uk',
#   'gender': 'Male',
#   'skill': 'Voiceovers',
#   'race': 'Chippewa'},
#  {'id': 26,
#   'first_name': 'Petronella',
#   'last_name': 'Denial',
#   'email': 'pdenialp@hp.com',
#   'gender': 'Female',
#   'skill': 'Star-CCM+',
#   'race': 'Samoan'},
#  {'id': 27,
#   'first_name': 'Angelo',
#   'last_name': 'Belfelt',
#   'email': 'abelfeltq@icio.us',
#   'gender': 'Male',
#   'skill': 'Ambulatory Care',
#   'race': 'Cheyenne'},
#  {'id': 28,
#   'first_name': 'Cathrin',
#   'last_name': 'Hulburd',
#   'email': 'chulburdr@cyberchimps.com',
#   'gender': 'Genderqueer',
#   'skill': 'TCR',
#   'race': 'Potawatomi'},
#  {'id': 29,
#   'first_name': 'Carmina',
#   'last_name': 'Marple',
#   'email': 'cmarples@businesswire.com',
#   'gender': 'Female',
#   'skill': 'Job Scheduling',
#   'race': 'Spaniard'},
#  {'id': 30,
#   'first_name': 'Garry',
#   'last_name': 'Minihane',
#   'email': 'gminihanet@topsy.com',
#   'gender': 'Bigender',
#   'skill': 'Drip Irrigation',
#   'race': 'Crow'},
#  {'id': 31,
#   'first_name': 'Calida',
#   'last_name': 'Stolte',
#   'email': 'cstolteu@acquirethisname.com',
#   'gender': 'Non-binary',
#   'skill': 'Market Planning',
#   'race': 'Uruguayan'},
#  {'id': 32,
#   'first_name': 'Gerrie',
#   'last_name': 'Vsanelli',
#   'email': 'gvsanelliv@washington.edu',
#   'gender': 'Male',
#   'skill': 'IFM',
#   'race': 'Eskimo'},
#  {'id': 33,
#   'first_name': 'Idette',
#   'last_name': 'Garwood',
#   'email': 'igarwoodw@skyrock.com',
#   'gender': 'Female',
#   'skill': 'Experimentation',
#   'race': 'Puerto Rican'},
#  {'id': 34,
#   'first_name': 'Charin',
#   'last_name': 'Harrill',
#   'email': 'charrillx@kickstarter.com',
#   'gender': 'Female',
#   'skill': 'CST Microwave Studio',
#   'race': 'Costa Rican'},
#  {'id': 35,
#   'first_name': 'Fae',
#   'last_name': 'Owbridge',
#   'email': 'fowbridgey@printfriendly.com',
#   'gender': 'Female',
#   'skill': 'HCV',
#   'race': 'Ecuadorian'},
#  {'id': 36,
#   'first_name': 'Turner',
#   'last_name': 'Pringley',
#   'email': 'tpringleyz@paypal.com',
#   'gender': 'Male',
#   'skill': 'Tablet PC',
#   'race': 'Chinese'},
#  {'id': 37,
#   'first_name': 'Madella',
#   'last_name': 'Breydin',
#   'email': 'mbreydin10@bluehost.com',
#   'gender': 'Female',
#   'skill': 'Komodo',
#   'race': 'Osage'},
#  {'id': 38,
#   'first_name': 'Clarisse',
#   'last_name': 'Sallings',
#   'email': 'csallings11@com.com',
#   'gender': 'Bigender',
#   'skill': 'Validation',
#   'race': 'Puerto Rican'},
#  {'id': 39,
#   'first_name': 'Mikkel',
#   'last_name': 'Scneider',
#   'email': 'mscneider12@nyu.edu',
#   'gender': 'Male',
#   'skill': 'Oceanography',
#   'race': 'Cree'},
#  {'id': 40,
#   'first_name': 'Mathew',
#   'last_name': 'Anderbrugge',
#   'email': 'manderbrugge13@people.com.cn',
#   'gender': 'Male',
#   'skill': 'Testing Types',
#   'race': 'Central American'},
#  {'id': 41,
#   'first_name': 'Chelsey',
#   'last_name': 'Ayer',
#   'email': 'cayer14@google.com',
#   'gender': 'Female',
#   'skill': 'Biochemistry',
#   'race': 'Shoshone'},
#  {'id': 42,
#   'first_name': 'Bekki',
#   'last_name': 'State',
#   'email': 'bstate15@gnu.org',
#   'gender': 'Female',
#   'skill': 'Heavy Oil',
#   'race': 'Costa Rican'},
#  {'id': 43,
#   'first_name': 'Olin',
#   'last_name': 'Baud',
#   'email': 'obaud16@e-recht24.de',
#   'gender': 'Polygender',
#   'skill': 'X-ray',
#   'race': 'Sri Lankan'},
#  {'id': 44,
#   'first_name': 'Leisha',
#   'last_name': 'Regglar',
#   'email': 'lregglar17@linkedin.com',
#   'gender': 'Female',
#   'skill': 'European Law',
#   'race': 'Chilean'},
#  {'id': 45,
#   'first_name': 'Ahmed',
#   'last_name': 'Strathern',
#   'email': 'astrathern18@walmart.com',
#   'gender': 'Male',
#   'skill': 'Target Costing',
#   'race': 'Osage'},
#  {'id': 46,
#   'first_name': 'Darryl',
#   'last_name': 'Connah',
#   'email': 'dconnah19@unc.edu',
#   'gender': 'Female',
#   'skill': 'Otology',
#   'race': 'Guamanian'},
#  {'id': 47,
#   'first_name': 'Kora',
#   'last_name': 'Sancto',
#   'email': 'ksancto1a@senate.gov',
#   'gender': 'Female',
#   'skill': 'Kenan FX',
#   'race': 'Guamanian'},
#  {'id': 48,
#   'first_name': 'Deedee',
#   'last_name': 'Margrie',
#   'email': 'dmargrie1b@arizona.edu',
#   'gender': 'Female',
#   'skill': 'PPPoE',
#   'race': 'Dominican (Dominican Republic)'},
#  {'id': 49,
#   'first_name': 'Becki',
#   'last_name': 'Presswell',
#   'email': 'bpresswell1c@xrea.com',
#   'gender': 'Female',
#   'skill': 'dSPACE',
#   'race': 'Pima'},
#  {'id': 50,
#   'first_name': 'Dov',
#   'last_name': 'Abramski',
#   'email': 'dabramski1d@deliciousdays.com',
#   'gender': 'Male',
#   'skill': 'RCS Selector',
#   'race': 'Cree'},
#  {'id': 51,
#   'first_name': 'Gillie',
#   'last_name': 'Gethings',
#   'email': 'ggethings1e@boston.com',
#   'gender': 'Female',
#   'skill': 'VPLS',
#   'race': 'Filipino'},
#  {'id': 52,
#   'first_name': 'Felicity',
#   'last_name': 'Candlin',
#   'email': 'fcandlin1f@engadget.com',
#   'gender': 'Female',
#   'skill': 'Utility Billing',
#   'race': 'Salvadoran'},
#  {'id': 53,
#   'first_name': 'Joete',
#   'last_name': 'Coffey',
#   'email': 'jcoffey1g@reverbnation.com',
#   'gender': 'Female',
#   'skill': 'QSAR',
#   'race': 'Paiute'},
#  {'id': 54,
#   'first_name': 'Jody',
#   'last_name': 'Laugier',
#   'email': 'jlaugier1h@g.co',
#   'gender': 'Male',
#   'skill': 'CD packaging',
#   'race': 'Melanesian'},
#  {'id': 55,
#   'first_name': 'Urbain',
#   'last_name': 'Gavey',
#   'email': 'ugavey1i@spotify.com',
#   'gender': 'Male',
#   'skill': 'FMLA',
#   'race': "Tohono O'Odham"},
#  {'id': 56,
#   'first_name': 'Rakel',
#   'last_name': 'Vittery',
#   'email': 'rvittery1j@cbc.ca',
#   'gender': 'Polygender',
#   'skill': 'International Tax',
#   'race': 'Lumbee'},
#  {'id': 57,
#   'first_name': 'Jeffie',
#   'last_name': 'Partleton',
#   'email': 'jpartleton1k@unblog.fr',
#   'gender': 'Male',
#   'skill': 'Wedding DJ',
#   'race': 'Blackfeet'},
#  {'id': 58,
#   'first_name': 'Mair',
#   'last_name': 'Buttrey',
#   'email': 'mbuttrey1l@nsw.gov.au',
#   'gender': 'Female',
#   'skill': 'Immigration Law',
#   'race': 'Chamorro'},
#  {'id': 59,
#   'first_name': 'Jeremias',
#   'last_name': 'Flack',
#   'email': 'jflack1m@ustream.tv',
#   'gender': 'Male',
#   'skill': 'Google Docs',
#   'race': 'Panamanian'},
#  {'id': 60,
#   'first_name': 'Karlan',
#   'last_name': 'Stebbing',
#   'email': 'kstebbing1n@comcast.net',
#   'gender': 'Male',
#   'skill': 'TPC',
#   'race': 'American Indian'},
#  {'id': 61,
#   'first_name': 'Estrellita',
#   'last_name': "O'Donovan",
#   'email': 'eodonovan1o@reference.com',
#   'gender': 'Female',
#   'skill': 'Snow',
#   'race': 'Asian Indian'},
#  {'id': 62,
#   'first_name': 'Caryn',
#   'last_name': 'Mallia',
#   'email': 'cmallia1p@washington.edu',
#   'gender': 'Female',
#   'skill': 'RTF',
#   'race': 'Kiowa'},
#  {'id': 63,
#   'first_name': 'Ag',
#   'last_name': 'Dearth',
#   'email': 'adearth1q@webmd.com',
#   'gender': 'Female',
#   'skill': 'DBI',
#   'race': 'Taiwanese'},
#  {'id': 64,
#   'first_name': 'Noami',
#   'last_name': 'Vickors',
#   'email': 'nvickors1r@arizona.edu',
#   'gender': 'Bigender',
#   'skill': 'Wind Turbines',
#   'race': 'Guamanian'},
#  {'id': 65,
#   'first_name': 'Larry',
#   'last_name': 'Peachman',
#   'email': 'lpeachman1s@github.io',
#   'gender': 'Male',
#   'skill': 'Osteopathy',
#   'race': 'White'},
#  {'id': 66,
#   'first_name': 'Vanda',
#   'last_name': 'Antoszczyk',
#   'email': 'vantoszczyk1t@tmall.com',
#   'gender': 'Female',
#   'skill': 'CD packaging',
#   'race': 'Sri Lankan'},
#  {'id': 67,
#   'first_name': 'Conney',
#   'last_name': 'Haldin',
#   'email': 'chaldin1u@com.com',
#   'gender': 'Male',
#   'skill': 'HF',
#   'race': 'Chamorro'},
#  {'id': 68,
#   'first_name': 'Sebastiano',
#   'last_name': 'Roiz',
#   'email': 'sroiz1v@about.me',
#   'gender': 'Male',
#   'skill': 'Workforce Development',
#   'race': 'Potawatomi'},
#  {'id': 69,
#   'first_name': 'Powell',
#   'last_name': 'Rawlings',
#   'email': 'prawlings1w@aboutads.info',
#   'gender': 'Male',
#   'skill': 'Canon XL2',
#   'race': 'Argentinian'},
#  {'id': 70,
#   'first_name': 'Hunfredo',
#   'last_name': 'Lacer',
#   'email': 'hlacer1x@tuttocitta.it',
#   'gender': 'Male',
#   'skill': 'Pinterest',
#   'race': 'Hmong'},
#  {'id': 71,
#   'first_name': 'Gustie',
#   'last_name': 'McCullagh',
#   'email': 'gmccullagh1y@pen.io',
#   'gender': 'Female',
#   'skill': 'Youth Entrepreneurship',
#   'race': 'Malaysian'},
#  {'id': 72,
#   'first_name': 'Isidore',
#   'last_name': 'Valerius',
#   'email': 'ivalerius1z@gmpg.org',
#   'gender': 'Male',
#   'skill': 'Mixed-Signal IC Design',
#   'race': 'Yuman'},
#  {'id': 73,
#   'first_name': 'Rori',
#   'last_name': 'Northage',
#   'email': 'rnorthage20@psu.edu',
#   'gender': 'Female',
#   'skill': 'Kaspersky',
#   'race': 'Bangladeshi'},
#  {'id': 74,
#   'first_name': 'Danny',
#   'last_name': 'Franchioni',
#   'email': 'dfranchioni21@cnn.com',
#   'gender': 'Genderfluid',
#   'skill': 'OTV',
#   'race': 'Spaniard'},
#  {'id': 75,
#   'first_name': 'Bernardina',
#   'last_name': 'Bradnick',
#   'email': 'bbradnick22@pcworld.com',
#   'gender': 'Female',
#   'skill': 'LDS',
#   'race': 'Peruvian'},
#  {'id': 76,
#   'first_name': 'Murial',
#   'last_name': 'Muglestone',
#   'email': 'mmuglestone23@symantec.com',
#   'gender': 'Female',
#   'skill': 'OGC',
#   'race': 'Pakistani'},
#  {'id': 77,
#   'first_name': 'Norry',
#   'last_name': 'Stubbings',
#   'email': 'nstubbings24@netscape.com',
#   'gender': 'Female',
#   'skill': 'Food Safety',
#   'race': 'Creek'},
#  {'id': 78,
#   'first_name': 'Norma',
#   'last_name': 'Metcalf',
#   'email': 'nmetcalf25@123-reg.co.uk',
#   'gender': 'Female',
#   'skill': 'Tiles',
#   'race': 'Filipino'},
#  {'id': 79,
#   'first_name': 'Munmro',
#   'last_name': 'Mattersey',
#   'email': 'mmattersey26@ftc.gov',
#   'gender': 'Male',
#   'skill': 'RF Circuits',
#   'race': 'Uruguayan'},
#  {'id': 80,
#   'first_name': 'Elicia',
#   'last_name': 'Keysel',
#   'email': 'ekeysel27@wordpress.org',
#   'gender': 'Female',
#   'skill': 'AAC',
#   'race': 'Osage'},
#  {'id': 81,
#   'first_name': 'Hart',
#   'last_name': 'Joannidi',
#   'email': 'hjoannidi28@instagram.com',
#   'gender': 'Male',
#   'skill': 'Coastal Zone Management',
#   'race': 'South American'},
#  {'id': 82,
#   'first_name': 'Nathanael',
#   'last_name': 'Salasar',
#   'email': 'nsalasar29@latimes.com',
#   'gender': 'Male',
#   'skill': 'HEC-HMS',
#   'race': 'Chinese'},
#  {'id': 83,
#   'first_name': 'Daven',
#   'last_name': 'Hegerty',
#   'email': 'dhegerty2a@fema.gov',
#   'gender': 'Male',
#   'skill': 'Carrier Ethernet',
#   'race': 'Osage'},
#  {'id': 84,
#   'first_name': 'Luciana',
#   'last_name': 'Gorry',
#   'email': 'lgorry2b@apple.com',
#   'gender': 'Female',
#   'skill': 'MQSI',
#   'race': 'Kiowa'},
#  {'id': 85,
#   'first_name': 'Stacy',
#   'last_name': 'Gornall',
#   'email': 'sgornall2c@adobe.com',
#   'gender': 'Male',
#   'skill': 'Www',
#   'race': 'Houma'},
#  {'id': 86,
#   'first_name': 'Nathaniel',
#   'last_name': 'Willets',
#   'email': 'nwillets2d@freewebs.com',
#   'gender': 'Polygender',
#   'skill': 'DVD Authoring',
#   'race': 'Cree'},
#  {'id': 87,
#   'first_name': 'Hanna',
#   'last_name': 'Fishlee',
#   'email': 'hfishlee2e@hatena.ne.jp',
#   'gender': 'Female',
#   'skill': 'Updos',
#   'race': 'Filipino'},
#  {'id': 88,
#   'first_name': 'Gene',
#   'last_name': 'Monnelly',
#   'email': 'gmonnelly2f@simplemachines.org',
#   'gender': 'Female',
#   'skill': 'Sanction II',
#   'race': 'Dominican (Dominican Republic)'},
#  {'id': 89,
#   'first_name': 'Clerc',
#   'last_name': 'Treble',
#   'email': 'ctreble2g@telegraph.co.uk',
#   'gender': 'Male',
#   'skill': 'xUnit',
#   'race': 'Comanche'},
#  {'id': 90,
#   'first_name': 'Terri',
#   'last_name': 'Sprasen',
#   'email': 'tsprasen2h@archive.org',
#   'gender': 'Male',
#   'skill': 'Long Distance Running',
#   'race': 'Panamanian'},
#  {'id': 91,
#   'first_name': 'Thurston',
#   'last_name': 'Whordley',
#   'email': 'twhordley2i@tiny.cc',
#   'gender': 'Male',
#   'skill': 'Service Delivery',
#   'race': 'Korean'},
#  {'id': 92,
#   'first_name': 'Thoma',
#   'last_name': 'Rubi',
#   'email': 'trubi2j@posterous.com',
#   'gender': 'Male',
#   'skill': 'Graphics',
#   'race': 'Melanesian'},
#  {'id': 93,
#   'first_name': 'Judie',
#   'last_name': 'Surmeir',
#   'email': 'jsurmeir2k@msn.com',
#   'gender': 'Female',
#   'skill': 'Nanoparticles',
#   'race': 'Sioux'},
#  {'id': 94,
#   'first_name': 'Janessa',
#   'last_name': 'Chipman',
#   'email': 'jchipman2l@cnet.com',
#   'gender': 'Female',
#   'skill': 'Internet Banking',
#   'race': 'Panamanian'},
#  {'id': 95,
#   'first_name': 'Keir',
#   'last_name': 'Probets',
#   'email': 'kprobets2m@myspace.com',
#   'gender': 'Male',
#   'skill': 'Electricity',
#   'race': 'American Indian and Alaska Native (AIAN)'},
#  {'id': 96,
#   'first_name': 'Sayer',
#   'last_name': 'Hingeley',
#   'email': 'shingeley2n@xrea.com',
#   'gender': 'Male',
#   'skill': 'PET-CT',
#   'race': 'Yakama'},
#  {'id': 97,
#   'first_name': 'Ransell',
#   'last_name': 'Astles',
#   'email': 'rastles2o@salon.com',
#   'gender': 'Male',
#   'skill': 'CGI programming',
#   'race': 'Seminole'},
#  {'id': 98,
#   'first_name': 'Karisa',
#   'last_name': 'Varndell',
#   'email': 'kvarndell2p@google.com.au',
#   'gender': 'Female',
#   'skill': 'Windows 7',
#   'race': 'Kiowa'},
#  {'id': 99,
#   'first_name': 'Carena',
#   'last_name': 'Lambrook',
#   'email': 'clambrook2q@hhs.gov',
#   'gender': 'Female',
#   'skill': 'Foreign Trade Zone',
#   'race': 'Crow'},
#  {'id': 100,
#   'first_name': 'Stephanie',
#   'last_name': 'Jopson',
#   'email': 'sjopson2r@vistaprint.com',
#   'gender': 'Female',
#   'skill': 'DMMs',
#   'race': 'Malaysian'},
#  {'id': 101,
#   'first_name': 'Gallard',
#   'last_name': 'Itzkovsky',
#   'email': 'gitzkovsky2s@cisco.com',
#   'gender': 'Male',
#   'skill': 'Overseas Experience',
#   'race': 'Latin American Indian'},
#  {'id': 102,
#   'first_name': 'Romola',
#   'last_name': 'Corragan',
#   'email': 'rcorragan2t@icq.com',
#   'gender': 'Female',
#   'skill': 'Stage Make-up',
#   'race': 'Argentinian'},
#  {'id': 103,
#   'first_name': 'Bethanne',
#   'last_name': 'Bearns',
#   'email': 'bbearns2u@123-reg.co.uk',
#   'gender': 'Female',
#   'skill': 'Waste Management',
#   'race': 'Tongan'},
#  {'id': 104,
#   'first_name': 'Cassy',
#   'last_name': 'Balderson',
#   'email': 'cbalderson2v@studiopress.com',
#   'gender': 'Female',
#   'skill': 'Broadband',
#   'race': 'Native Hawaiian and Other Pacific Islander (NHPI)'},
#  {'id': 105,
#   'first_name': 'Muhammad',
#   'last_name': 'Oleksiak',
#   'email': 'moleksiak2w@google.com.br',
#   'gender': 'Male',
#   'skill': 'Whiplash',
#   'race': 'Sri Lankan'},
#  {'id': 106,
#   'first_name': 'Andriana',
#   'last_name': 'Newitt',
#   'email': 'anewitt2x@ocn.ne.jp',
#   'gender': 'Female',
#   'skill': 'Online Gaming',
#   'race': "Tohono O'Odham"},
#  {'id': 107,
#   'first_name': 'Pattie',
#   'last_name': 'Phateplace',
#   'email': 'pphateplace2y@is.gd',
#   'gender': 'Female',
#   'skill': 'Subcontracting',
#   'race': 'Peruvian'},
#  {'id': 108,
#   'first_name': 'Flory',
#   'last_name': 'Clineck',
#   'email': 'fclineck2z@ifeng.com',
#   'gender': 'Male',
#   'skill': 'NS-2',
#   'race': 'Samoan'},
#  {'id': 109,
#   'first_name': 'Merell',
#   'last_name': 'Geratt',
#   'email': 'mgeratt30@cbsnews.com',
#   'gender': 'Male',
#   'skill': 'Microsoft Publisher',
#   'race': 'Navajo'},
#  {'id': 110,
#   'first_name': 'Marten',
#   'last_name': 'Cuerda',
#   'email': 'mcuerda31@ask.com',
#   'gender': 'Male',
#   'skill': 'Newspapers',
#   'race': 'Colville'},
#  {'id': 111,
#   'first_name': 'Sully',
#   'last_name': 'Agus',
#   'email': 'sagus32@i2i.jp',
#   'gender': 'Male',
#   'skill': 'Financial Services',
#   'race': 'Navajo'},
#  {'id': 112,
#   'first_name': 'Isidro',
#   'last_name': 'McIlvenny',
#   'email': 'imcilvenny33@squarespace.com',
#   'gender': 'Male',
#   'skill': 'Logo Design',
#   'race': 'Chippewa'},
#  {'id': 113,
#   'first_name': 'Jessamine',
#   'last_name': 'Kerwood',
#   'email': 'jkerwood34@blogspot.com',
#   'gender': 'Female',
#   'skill': 'Attendance Management',
#   'race': 'Alaska Native'},
#  {'id': 114,
#   'first_name': 'Bridie',
#   'last_name': 'Schottli',
#   'email': 'bschottli35@sourceforge.net',
#   'gender': 'Female',
#   'skill': 'CentOS',
#   'race': 'Japanese'},
#  {'id': 115,
#   'first_name': 'Mohammed',
#   'last_name': 'Bentjens',
#   'email': 'mbentjens36@omniture.com',
#   'gender': 'Male',
#   'skill': 'SOA BPEL',
#   'race': 'Guamanian'},
#  {'id': 116,
#   'first_name': 'Cathee',
#   'last_name': 'Feavers',
#   'email': 'cfeavers37@cdbaby.com',
#   'gender': 'Female',
#   'skill': 'Estimates',
#   'race': 'Cambodian'},
#  {'id': 117,
#   'first_name': 'Roana',
#   'last_name': 'Pashbee',
#   'email': 'rpashbee38@ustream.tv',
#   'gender': 'Female',
#   'skill': 'MSI',
#   'race': 'Navajo'},
#  {'id': 118,
#   'first_name': 'Hollyanne',
#   'last_name': 'Bootes',
#   'email': 'hbootes39@nationalgeographic.com',
#   'gender': 'Female',
#   'skill': 'Youth Empowerment',
#   'race': 'Polynesian'},
#  {'id': 119,
#   'first_name': 'Burnard',
#   'last_name': 'Billitteri',
#   'email': 'bbillitteri3a@globo.com',
#   'gender': 'Male',
#   'skill': 'iFix',
#   'race': 'Native Hawaiian and Other Pacific Islander (NHPI)'},
#  {'id': 120,
#   'first_name': 'Rosco',
#   'last_name': 'Gimblett',
#   'email': 'rgimblett3b@hatena.ne.jp',
#   'gender': 'Male',
#   'skill': 'CGI',
#   'race': 'Eskimo'},
#  {'id': 121,
#   'first_name': 'Maridel',
#   'last_name': 'Pergens',
#   'email': 'mpergens3c@shutterfly.com',
#   'gender': 'Female',
#   'skill': 'Wealth Management',
#   'race': 'Ottawa'},
#  {'id': 122,
#   'first_name': 'Dame',
#   'last_name': 'Bettles',
#   'email': 'dbettles3d@mapy.cz',
#   'gender': 'Male',
#   'skill': 'DBWorks',
#   'race': 'Tongan'},
#  {'id': 123,
#   'first_name': 'Marlyn',
#   'last_name': 'Worsalls',
#   'email': 'mworsalls3e@prnewswire.com',
#   'gender': 'Female',
#   'skill': 'Training Delivery',
#   'race': 'Polynesian'},
#  {'id': 124,
#   'first_name': 'Midge',
#   'last_name': 'Dakhno',
#   'email': 'mdakhno3f@rediff.com',
#   'gender': 'Female',
#   'skill': 'Database Administration',
#   'race': 'Sri Lankan'},
#  {'id': 125,
#   'first_name': 'Oswell',
#   'last_name': 'Thumann',
#   'email': 'othumann3g@opensource.org',
#   'gender': 'Male',
#   'skill': 'Novell Netware',
#   'race': 'Native Hawaiian'},
#  {'id': 126,
#   'first_name': 'Duky',
#   'last_name': 'Crosswaite',
#   'email': 'dcrosswaite3h@opera.com',
#   'gender': 'Male',
#   'skill': 'MLOAD',
#   'race': 'Guatemalan'},
#  {'id': 127,
#   'first_name': 'Karlotta',
#   'last_name': 'Crannell',
#   'email': 'kcrannell3i@flickr.com',
#   'gender': 'Female',
#   'skill': 'ILOG',
#   'race': 'Lumbee'},
#  {'id': 128,
#   'first_name': 'Winni',
#   'last_name': 'Flanne',
#   'email': 'wflanne3j@so-net.ne.jp',
#   'gender': 'Female',
#   'skill': 'Physical Security',
#   'race': 'Fijian'},
#  {'id': 129,
#   'first_name': 'Ula',
#   'last_name': 'Allchorn',
#   'email': 'uallchorn3k@adobe.com',
#   'gender': 'Female',
#   'skill': 'SWOT analysis',
#   'race': 'Pueblo'},
#  {'id': 130,
#   'first_name': 'Abba',
#   'last_name': 'Firman',
#   'email': 'afirman3l@studiopress.com',
#   'gender': 'Male',
#   'skill': 'Mobile Devices',
#   'race': 'Iroquois'},
#  {'id': 131,
#   'first_name': 'Thadeus',
#   'last_name': 'Morales',
#   'email': 'tmorales3m@sogou.com',
#   'gender': 'Male',
#   'skill': 'Online Research',
#   'race': 'White'},
#  {'id': 132,
#   'first_name': 'Brady',
#   'last_name': 'Poznan',
#   'email': 'bpoznan3n@uiuc.edu',
#   'gender': 'Male',
#   'skill': 'RRSP',
#   'race': 'Dominican (Dominican Republic)'},
#  {'id': 133,
#   'first_name': 'Helyn',
#   'last_name': 'Berdale',
#   'email': 'hberdale3o@shinystat.com',
#   'gender': 'Female',
#   'skill': 'HR Consulting',
#   'race': 'Chinese'},
#  {'id': 134,
#   'first_name': 'Arny',
#   'last_name': 'Mussared',
#   'email': 'amussared3p@theatlantic.com',
#   'gender': 'Male',
#   'skill': 'WPS',
#   'race': 'Ute'},
#  {'id': 135,
#   'first_name': 'Franny',
#   'last_name': 'Giorgeschi',
#   'email': 'fgiorgeschi3q@nifty.com',
#   'gender': 'Male',
#   'skill': 'TF-CBT',
#   'race': 'Cree'},
#  {'id': 136,
#   'first_name': 'Heidie',
#   'last_name': 'Besnard',
#   'email': 'hbesnard3r@last.fm',
#   'gender': 'Female',
#   'skill': 'Academic Writing',
#   'race': 'Sri Lankan'},
#  {'id': 137,
#   'first_name': 'Montague',
#   'last_name': 'Croome',
#   'email': 'mcroome3s@cnet.com',
#   'gender': 'Male',
#   'skill': 'QCAT',
#   'race': 'Cambodian'},
#  {'id': 138,
#   'first_name': 'Erastus',
#   'last_name': 'Tellwright',
#   'email': 'etellwright3t@myspace.com',
#   'gender': 'Male',
#   'skill': 'WLM',
#   'race': 'Cherokee'},
#  {'id': 139,
#   'first_name': 'Lanita',
#   'last_name': 'Tincknell',
#   'email': 'ltincknell3u@wordpress.com',
#   'gender': 'Female',
#   'skill': 'WFO',
#   'race': 'Comanche'},
#  {'id': 140,
#   'first_name': 'Marthe',
#   'last_name': 'Labone',
#   'email': 'mlabone3v@facebook.com',
#   'gender': 'Female',
#   'skill': 'Radio',
#   'race': 'Tongan'},
#  {'id': 141,
#   'first_name': 'Rozelle',
#   'last_name': 'Bauldry',
#   'email': 'rbauldry3w@miitbeian.gov.cn',
#   'gender': 'Female',
#   'skill': 'XDCAM',
#   'race': 'Paiute'},
#  {'id': 142,
#   'first_name': 'Lorenzo',
#   'last_name': 'Sorsbie',
#   'email': 'lsorsbie3x@cargocollective.com',
#   'gender': 'Male',
#   'skill': 'Event Management',
#   'race': 'Yaqui'},
#  {'id': 143,
#   'first_name': 'Dallas',
#   'last_name': 'Barnicott',
#   'email': 'dbarnicott3y@loc.gov',
#   'gender': 'Male',
#   'skill': 'NPV',
#   'race': 'Comanche'},
#  {'id': 144,
#   'first_name': 'Darice',
#   'last_name': 'Dangl',
#   'email': 'ddangl3z@state.gov',
#   'gender': 'Female',
#   'skill': 'Competitive Analysis',
#   'race': 'Osage'},
#  {'id': 145,
#   'first_name': 'Corty',
#   'last_name': 'Toxell',
#   'email': 'ctoxell40@berkeley.edu',
#   'gender': 'Male',
#   'skill': 'CCIE',
#   'race': 'Paraguayan'},
#  {'id': 146,
#   'first_name': 'Cliff',
#   'last_name': 'Shortall',
#   'email': 'cshortall41@pcworld.com',
#   'gender': 'Non-binary',
#   'skill': 'Revenue Cycle',
#   'race': 'Puget Sound Salish'},
#  {'id': 147,
#   'first_name': 'Erna',
#   'last_name': 'Perulli',
#   'email': 'eperulli42@prlog.org',
#   'gender': 'Female',
#   'skill': 'LPAR',
#   'race': 'Nicaraguan'},
#  {'id': 148,
#   'first_name': 'Roy',
#   'last_name': 'Davsley',
#   'email': 'rdavsley43@surveymonkey.com',
#   'gender': 'Male',
#   'skill': 'SQL DB2',
#   'race': 'Mexican'},
#  {'id': 149,
#   'first_name': 'Ewell',
#   'last_name': 'Rauprich',
#   'email': 'erauprich44@theatlantic.com',
#   'gender': 'Male',
#   'skill': 'Xerox Printers',
#   'race': 'Polynesian'},
#  {'id': 150,
#   'first_name': 'Correy',
#   'last_name': 'Regan',
#   'email': 'cregan45@ca.gov',
#   'gender': 'Male',
#   'skill': 'TSP',
#   'race': 'Shoshone'},
#  {'id': 151,
#   'first_name': 'Xylia',
#   'last_name': 'Ridgers',
#   'email': 'xridgers46@over-blog.com',
#   'gender': 'Female',
#   'skill': 'Animal Husbandry',
#   'race': 'White'},
#  {'id': 152,
#   'first_name': 'Dene',
#   'last_name': 'Tissier',
#   'email': 'dtissier47@wired.com',
#   'gender': 'Male',
#   'skill': 'HR Management',
#   'race': 'Colville'},
#  {'id': 153,
#   'first_name': 'Kin',
#   'last_name': 'Bellison',
#   'email': 'kbellison48@jimdo.com',
#   'gender': 'Male',
#   'skill': 'LPG',
#   'race': 'Samoan'},
#  {'id': 154,
#   'first_name': 'Stoddard',
#   'last_name': 'Raiston',
#   'email': 'sraiston49@instagram.com',
#   'gender': 'Female',
#   'skill': 'Early Intervention',
#   'race': 'Indonesian'},
#  {'id': 155,
#   'first_name': 'Yuma',
#   'last_name': 'Longforth',
#   'email': 'ylongforth4a@addtoany.com',
#   'gender': 'Male',
#   'skill': 'HSE Management Systems',
#   'race': 'Alaskan Athabascan'},
#  {'id': 156,
#   'first_name': 'Sarette',
#   'last_name': 'Adamovich',
#   'email': 'sadamovich4b@networksolutions.com',
#   'gender': 'Female',
#   'skill': 'DVD Architect',
#   'race': 'Asian Indian'},
#  {'id': 157,
#   'first_name': 'Collie',
#   'last_name': 'Inker',
#   'email': 'cinker4c@kickstarter.com',
#   'gender': 'Female',
#   'skill': 'PPE',
#   'race': 'Alaska Native'},
#  {'id': 158,
#   'first_name': 'Duff',
#   'last_name': 'McKane',
#   'email': 'dmckane4d@umich.edu',
#   'gender': 'Male',
#   'skill': 'JSR 168',
#   'race': 'Pakistani'},
#  {'id': 159,
#   'first_name': 'Jermaine',
#   'last_name': 'Olney',
#   'email': 'jolney4e@archive.org',
#   'gender': 'Male',
#   'skill': 'FTP',
#   'race': 'Iroquois'},
#  {'id': 160,
#   'first_name': 'Jarvis',
#   'last_name': 'Caudwell',
#   'email': 'jcaudwell4f@t-online.de',
#   'gender': 'Male',
#   'skill': 'BPL',
#   'race': 'Indonesian'},
#  {'id': 161,
#   'first_name': 'Gery',
#   'last_name': 'Devenish',
#   'email': 'gdevenish4g@newsvine.com',
#   'gender': 'Male',
#   'skill': 'Military Aviation',
#   'race': 'Costa Rican'},
#  {'id': 162,
#   'first_name': 'Stern',
#   'last_name': 'Probbings',
#   'email': 'sprobbings4h@bigcartel.com',
#   'gender': 'Male',
#   'skill': 'Urban',
#   'race': 'Costa Rican'},
#  {'id': 163,
#   'first_name': 'Heda',
#   'last_name': 'Goghin',
#   'email': 'hgoghin4i@networksolutions.com',
#   'gender': 'Female',
#   'skill': 'Vacation Homes',
#   'race': 'Chippewa'},
#  {'id': 164,
#   'first_name': 'Dewitt',
#   'last_name': 'De Vile',
#   'email': 'ddevile4j@upenn.edu',
#   'gender': 'Male',
#   'skill': 'Creative Non-fiction',
#   'race': 'Cheyenne'},
#  {'id': 165,
#   'first_name': 'Dianne',
#   'last_name': 'Peedell',
#   'email': 'dpeedell4k@businessweek.com',
#   'gender': 'Female',
#   'skill': 'FDA',
#   'race': 'Venezuelan'},
#  {'id': 166,
#   'first_name': 'Tadeas',
#   'last_name': 'MacGinley',
#   'email': 'tmacginley4l@japanpost.jp',
#   'gender': 'Male',
#   'skill': 'Lotus Notes',
#   'race': 'Ute'},
#  {'id': 167,
#   'first_name': 'Enoch',
#   'last_name': 'Flarity',
#   'email': 'eflarity4m@odnoklassniki.ru',
#   'gender': 'Male',
#   'skill': 'Krakatoa',
#   'race': 'Cherokee'},
#  {'id': 168,
#   'first_name': 'Ike',
#   'last_name': 'Tumielli',
#   'email': 'itumielli4n@thetimes.co.uk',
#   'gender': 'Male',
#   'skill': 'Bit.ly',
#   'race': 'Kiowa'},
#  {'id': 169,
#   'first_name': 'Darb',
#   'last_name': 'Keward',
#   'email': 'dkeward4o@usgs.gov',
#   'gender': 'Male',
#   'skill': 'XQuery',
#   'race': 'Taiwanese'},
#  {'id': 170,
#   'first_name': 'Jacinta',
#   'last_name': 'Hooban',
#   'email': 'jhooban4p@ucoz.com',
#   'gender': 'Female',
#   'skill': 'Oil &amp; Gas Services',
#   'race': 'Sioux'},
#  {'id': 171,
#   'first_name': 'Madonna',
#   'last_name': 'Seywood',
#   'email': 'mseywood4q@soundcloud.com',
#   'gender': 'Female',
#   'skill': 'vShield',
#   'race': 'Cheyenne'},
#  {'id': 172,
#   'first_name': 'Marthe',
#   'last_name': 'Wetwood',
#   'email': 'mwetwood4r@zdnet.com',
#   'gender': 'Female',
#   'skill': 'Sculpture',
#   'race': 'American Indian and Alaska Native (AIAN)'},
#  {'id': 173,
#   'first_name': 'Bentley',
#   'last_name': 'Mitroshinov',
#   'email': 'bmitroshinov4s@histats.com',
#   'gender': 'Male',
#   'skill': 'DNA',
#   'race': 'Navajo'},
#  {'id': 174,
#   'first_name': 'Sheff',
#   'last_name': 'Sammonds',
#   'email': 'ssammonds4t@instagram.com',
#   'gender': 'Male',
#   'skill': 'MP3',
#   'race': 'Puerto Rican'},
#  {'id': 175,
#   'first_name': 'Joseph',
#   'last_name': 'Janoschek',
#   'email': 'jjanoschek4u@tripadvisor.com',
#   'gender': 'Male',
#   'skill': 'Eplan',
#   'race': 'Paraguayan'},
#  {'id': 176,
#   'first_name': 'Paul',
#   'last_name': 'Stace',
#   'email': 'pstace4v@miibeian.gov.cn',
#   'gender': 'Male',
#   'skill': 'LS9',
#   'race': 'Yakama'},
#  {'id': 177,
#   'first_name': 'Saundra',
#   'last_name': 'Meech',
#   'email': 'smeech4w@guardian.co.uk',
#   'gender': 'Male',
#   'skill': 'KRA',
#   'race': 'Tlingit-Haida'},
#  {'id': 178,
#   'first_name': 'Any',
#   'last_name': 'Gibbeson',
#   'email': 'agibbeson4x@forbes.com',
#   'gender': 'Male',
#   'skill': 'Start-up Consulting',
#   'race': 'Spaniard'},
#  {'id': 179,
#   'first_name': 'Beatrisa',
#   'last_name': 'MacPaden',
#   'email': 'bmacpaden4y@washingtonpost.com',
#   'gender': 'Female',
#   'skill': 'IB',
#   'race': 'Tlingit-Haida'},
#  {'id': 180,
#   'first_name': 'Jory',
#   'last_name': 'Spedroni',
#   'email': 'jspedroni4z@gmpg.org',
#   'gender': 'Male',
#   'skill': 'Property &amp; Casualty Insurance',
#   'race': 'Native Hawaiian and Other Pacific Islander (NHPI)'},
#  {'id': 181,
#   'first_name': 'Madalyn',
#   'last_name': 'Iianon',
#   'email': 'miianon50@tmall.com',
#   'gender': 'Female',
#   'skill': 'RDC',
#   'race': "Tohono O'Odham"},
#  {'id': 182,
#   'first_name': 'Parrnell',
#   'last_name': 'Trundell',
#   'email': 'ptrundell51@amazon.de',
#   'gender': 'Male',
#   'skill': 'HFM',
#   'race': 'Houma'},
#  {'id': 183,
#   'first_name': 'Gifford',
#   'last_name': 'Arendsen',
#   'email': 'garendsen52@hc360.com',
#   'gender': 'Male',
#   'skill': 'IRAs',
#   'race': 'Tongan'},
#  {'id': 184,
#   'first_name': 'Madlin',
#   'last_name': 'Cronchey',
#   'email': 'mcronchey53@chron.com',
#   'gender': 'Female',
#   'skill': 'iLife',
#   'race': "Tohono O'Odham"},
#  {'id': 185,
#   'first_name': 'Edita',
#   'last_name': 'Twell',
#   'email': 'etwell54@japanpost.jp',
#   'gender': 'Female',
#   'skill': 'XML Schema',
#   'race': 'Hmong'},
#  {'id': 186,
#   'first_name': 'Devon',
#   'last_name': 'Ozintsev',
#   'email': 'dozintsev55@ca.gov',
#   'gender': 'Female',
#   'skill': 'Assurance',
#   'race': 'Indonesian'},
#  {'id': 187,
#   'first_name': 'Kaine',
#   'last_name': 'Legerton',
#   'email': 'klegerton56@blogtalkradio.com',
#   'gender': 'Male',
#   'skill': 'cGMP practices',
#   'race': 'Vietnamese'},
#  {'id': 188,
#   'first_name': 'Kory',
#   'last_name': 'Gallafant',
#   'email': 'kgallafant57@bloglines.com',
#   'gender': 'Male',
#   'skill': 'Ion Chromatography',
#   'race': 'Taiwanese'},
#  {'id': 189,
#   'first_name': 'Darlleen',
#   'last_name': 'Le Fleming',
#   'email': 'dlefleming58@oaic.gov.au',
#   'gender': 'Genderqueer',
#   'skill': 'Storage',
#   'race': 'Cherokee'},
#  {'id': 190,
#   'first_name': 'Shel',
#   'last_name': 'Bartomeu',
#   'email': 'sbartomeu59@bloglines.com',
#   'gender': 'Female',
#   'skill': 'GPS Units',
#   'race': 'Guamanian'},
#  {'id': 191,
#   'first_name': 'Georgine',
#   'last_name': 'Erangy',
#   'email': 'gerangy5a@epa.gov',
#   'gender': 'Female',
#   'skill': 'HTRF',
#   'race': 'Latin American Indian'},
#  {'id': 192,
#   'first_name': 'Hilde',
#   'last_name': 'Eytel',
#   'email': 'heytel5b@google.de',
#   'gender': 'Female',
#   'skill': 'XML Sitemaps',
#   'race': 'Chilean'},
#  {'id': 193,
#   'first_name': 'Antonin',
#   'last_name': 'Slorach',
#   'email': 'aslorach5c@stanford.edu',
#   'gender': 'Male',
#   'skill': 'Fractional Ownership',
#   'race': 'Cheyenne'},
#  {'id': 194,
#   'first_name': 'Paxton',
#   'last_name': 'Glantz',
#   'email': 'pglantz5d@google.pl',
#   'gender': 'Male',
#   'skill': 'Object Oriented Perl',
#   'race': 'Houma'},
#  {'id': 195,
#   'first_name': 'Rosaline',
#   'last_name': 'Kubica',
#   'email': 'rkubica5e@toplist.cz',
#   'gender': 'Female',
#   'skill': 'Forklift Operation',
#   'race': 'Navajo'},
#  {'id': 196,
#   'first_name': 'Heinrick',
#   'last_name': 'Abby',
#   'email': 'habby5f@lycos.com',
#   'gender': 'Male',
#   'skill': 'Teaching',
#   'race': 'Paiute'},
#  {'id': 197,
#   'first_name': 'Cyrille',
#   'last_name': 'Lyall',
#   'email': 'clyall5g@ow.ly',
#   'gender': 'Male',
#   'skill': 'Slideshare',
#   'race': 'Yakama'},
#  {'id': 198,
#   'first_name': 'Taryn',
#   'last_name': 'Thews',
#   'email': 'tthews5h@time.com',
#   'gender': 'Female',
#   'skill': 'RDFS',
#   'race': "Tohono O'Odham"},
#  {'id': 199,
#   'first_name': 'Giacopo',
#   'last_name': 'Roon',
#   'email': 'groon5i@mit.edu',
#   'gender': 'Genderqueer',
#   'skill': 'Windows NT',
#   'race': 'Paraguayan'},
#  {'id': 200,
#   'first_name': 'Elladine',
#   'last_name': 'Girardeau',
#   'email': 'egirardeau5j@last.fm',
#   'gender': 'Female',
#   'skill': 'Curriculum Design',
#   'race': 'Kiowa'},
#  {'id': 201,
#   'first_name': 'Seka',
#   'last_name': 'Delacourt',
#   'email': 'sdelacourt5k@tripadvisor.com',
#   'gender': 'Female',
#   'skill': 'Classical',
#   'race': 'Asian Indian'},
#  {'id': 202,
#   'first_name': 'Virgie',
#   'last_name': 'Sandiland',
#   'email': 'vsandiland5l@de.vu',
#   'gender': 'Male',
#   'skill': 'Gstreamer',
#   'race': 'Ecuadorian'},
#  {'id': 203,
#   'first_name': 'Clayton',
#   'last_name': 'Wendover',
#   'email': 'cwendover5m@yale.edu',
#   'gender': 'Male',
#   'skill': 'SDLC',
#   'race': 'Cuban'},
#  {'id': 204,
#   'first_name': 'Saxe',
#   'last_name': 'Clappson',
#   'email': 'sclappson5n@prweb.com',
#   'gender': 'Male',
#   'skill': 'CICS',
#   'race': 'Costa Rican'},
#  {'id': 205,
#   'first_name': 'Rosella',
#   'last_name': 'Copas',
#   'email': 'rcopas5o@toplist.cz',
#   'gender': 'Female',
#   'skill': 'Pro II',
#   'race': 'Chilean'},
#  {'id': 206,
#   'first_name': 'Marcia',
#   'last_name': 'Trevena',
#   'email': 'mtrevena5p@huffingtonpost.com',
#   'gender': 'Agender',
#   'skill': 'AODA',
#   'race': 'Choctaw'},
#  {'id': 207,
#   'first_name': 'Darby',
#   'last_name': 'Shuxsmith',
#   'email': 'dshuxsmith5q@cbslocal.com',
#   'gender': 'Male',
#   'skill': 'Qooxdoo',
#   'race': 'Pueblo'},
#  {'id': 208,
#   'first_name': 'Sosanna',
#   'last_name': 'Wakeford',
#   'email': 'swakeford5r@digg.com',
#   'gender': 'Female',
#   'skill': 'Creative Strategy',
#   'race': 'Choctaw'},
#  {'id': 209,
#   'first_name': 'Eulalie',
#   'last_name': 'Labell',
#   'email': 'elabell5s@jigsy.com',
#   'gender': 'Female',
#   'skill': 'MKS',
#   'race': 'Micronesian'},
#  {'id': 210,
#   'first_name': 'Bernie',
#   'last_name': 'Bernaldo',
#   'email': 'bbernaldo5t@hubpages.com',
#   'gender': 'Male',
#   'skill': 'DBUnit',
#   'race': 'Chinese'},
#  {'id': 211,
#   'first_name': 'Forrester',
#   'last_name': 'Abbison',
#   'email': 'fabbison5u@cbc.ca',
#   'gender': 'Male',
#   'skill': 'CNC Programing',
#   'race': 'Navajo'},
#  {'id': 212,
#   'first_name': 'Skip',
#   'last_name': 'Hebditch',
#   'email': 'shebditch5v@yellowbook.com',
#   'gender': 'Male',
#   'skill': 'IKE',
#   'race': 'Asian'},
#  {'id': 213,
#   'first_name': 'Stillmann',
#   'last_name': 'Farney',
#   'email': 'sfarney5w@trellian.com',
#   'gender': 'Male',
#   'skill': 'Quest vWorkspace',
#   'race': 'Yuman'},
#  {'id': 214,
#   'first_name': 'Delcina',
#   'last_name': 'Overy',
#   'email': 'dovery5x@whitehouse.gov',
#   'gender': 'Female',
#   'skill': 'NMLS Licensed',
#   'race': 'Lumbee'},
#  {'id': 215,
#   'first_name': 'Savina',
#   'last_name': 'Wyllie',
#   'email': 'swyllie5y@wordpress.com',
#   'gender': 'Female',
#   'skill': 'CPE',
#   'race': 'Honduran'},
#  {'id': 216,
#   'first_name': 'Ingar',
#   'last_name': 'Malthouse',
#   'email': 'imalthouse5z@uiuc.edu',
#   'gender': 'Agender',
#   'skill': 'Policy Writing',
#   'race': 'Black or African American'},
#  {'id': 217,
#   'first_name': 'Babb',
#   'last_name': 'Gladstone',
#   'email': 'bgladstone60@unicef.org',
#   'gender': 'Female',
#   'skill': 'Start-up Ventures',
#   'race': 'Filipino'},
#  {'id': 218,
#   'first_name': 'Nerita',
#   'last_name': 'Oloman',
#   'email': 'noloman61@loc.gov',
#   'gender': 'Female',
#   'skill': 'DCOM',
#   'race': 'Choctaw'},
#  {'id': 219,
#   'first_name': 'Biron',
#   'last_name': 'Diano',
#   'email': 'bdiano62@telegraph.co.uk',
#   'gender': 'Male',
#   'skill': 'Flash',
#   'race': 'Eskimo'},
#  {'id': 220,
#   'first_name': 'Sander',
#   'last_name': 'Tilly',
#   'email': 'stilly63@hhs.gov',
#   'gender': 'Male',
#   'skill': 'Interviewing Skills',
#   'race': 'Yakama'},
#  {'id': 221,
#   'first_name': 'Wileen',
#   'last_name': 'Bunford',
#   'email': 'wbunford64@bloglines.com',
#   'gender': 'Genderfluid',
#   'skill': 'Digital Imaging',
#   'race': 'Micronesian'},
#  {'id': 222,
#   'first_name': 'Larisa',
#   'last_name': 'Bagehot',
#   'email': 'lbagehot65@creativecommons.org',
#   'gender': 'Female',
#   'skill': 'RTDS',
#   'race': 'Polynesian'},
#  {'id': 223,
#   'first_name': 'Genevieve',
#   'last_name': 'MacGray',
#   'email': 'gmacgray66@csmonitor.com',
#   'gender': 'Female',
#   'skill': 'Volleyball',
#   'race': 'Dominican (Dominican Republic)'},
#  {'id': 224,
#   'first_name': 'Isak',
#   'last_name': 'Aburrow',
#   'email': 'iaburrow67@4shared.com',
#   'gender': 'Male',
#   'skill': 'Ukrainian',
#   'race': 'Ute'},
#  {'id': 225,
#   'first_name': 'Jessamine',
#   'last_name': 'Noquet',
#   'email': 'jnoquet68@weibo.com',
#   'gender': 'Female',
#   'skill': 'People Management',
#   'race': 'Paraguayan'},
#  {'id': 226,
#   'first_name': 'Baudoin',
#   'last_name': 'Fitzroy',
#   'email': 'bfitzroy69@engadget.com',
#   'gender': 'Male',
#   'skill': 'Aesthetic Surgery',
#   'race': 'Bangladeshi'},
#  {'id': 227,
#   'first_name': 'Maynord',
#   'last_name': 'Tarry',
#   'email': 'mtarry6a@tuttocitta.it',
#   'gender': 'Male',
#   'skill': 'BLS',
#   'race': 'Latin American Indian'},
#  {'id': 228,
#   'first_name': 'Abbott',
#   'last_name': 'Grimley',
#   'email': 'agrimley6b@dedecms.com',
#   'gender': 'Male',
#   'skill': 'PTLLS',
#   'race': 'Colombian'},
#  {'id': 229,
#   'first_name': 'Parry',
#   'last_name': 'Mockler',
#   'email': 'pmockler6c@ted.com',
#   'gender': 'Male',
#   'skill': 'Emergency Management',
#   'race': 'Puget Sound Salish'},
#  {'id': 230,
#   'first_name': 'Had',
#   'last_name': 'Cannon',
#   'email': 'hcannon6d@upenn.edu',
#   'gender': 'Male',
#   'skill': 'Health Education',
#   'race': 'Colombian'},
#  {'id': 231,
#   'first_name': 'Dode',
#   'last_name': 'Gillingwater',
#   'email': 'dgillingwater6e@de.vu',
#   'gender': 'Female',
#   'skill': 'TQC',
#   'race': 'Taiwanese'},
#  {'id': 232,
#   'first_name': 'Charmane',
#   'last_name': 'Harris',
#   'email': 'charris6f@washington.edu',
#   'gender': 'Female',
#   'skill': 'SBMS',
#   'race': 'Samoan'},
#  {'id': 233,
#   'first_name': 'Jehu',
#   'last_name': "O'Shea",
#   'email': 'joshea6g@unblog.fr',
#   'gender': 'Male',
#   'skill': 'Zinc',
#   'race': 'Salvadoran'},
#  {'id': 234,
#   'first_name': 'Maggy',
#   'last_name': 'Inglis',
#   'email': 'minglis6h@vistaprint.com',
#   'gender': 'Female',
#   'skill': 'SAP',
#   'race': 'Native Hawaiian'},
#  {'id': 235,
#   'first_name': 'Gaylord',
#   'last_name': 'Broschek',
#   'email': 'gbroschek6i@unc.edu',
#   'gender': 'Male',
#   'skill': 'OTA',
#   'race': 'Puget Sound Salish'},
#  {'id': 236,
#   'first_name': 'Ertha',
#   'last_name': 'Matashkin',
#   'email': 'ematashkin6j@comcast.net',
#   'gender': 'Female',
#   'skill': 'VTune',
#   'race': 'Cree'},
#  {'id': 237,
#   'first_name': 'Alvin',
#   'last_name': 'Charker',
#   'email': 'acharker6k@eepurl.com',
#   'gender': 'Male',
#   'skill': 'MXML',
#   'race': 'Bangladeshi'},
#  {'id': 238,
#   'first_name': 'Zorah',
#   'last_name': 'Sadat',
#   'email': 'zsadat6l@businesswire.com',
#   'gender': 'Genderfluid',
#   'skill': 'PPAP',
#   'race': 'Yaqui'},
#  {'id': 239,
#   'first_name': 'Evelyn',
#   'last_name': 'Rawne',
#   'email': 'erawne6m@apple.com',
#   'gender': 'Male',
#   'skill': 'Luxury Lifestyle',
#   'race': 'Pueblo'},
#  {'id': 240,
#   'first_name': 'Ashli',
#   'last_name': 'Titman',
#   'email': 'atitman6n@yolasite.com',
#   'gender': 'Female',
#   'skill': 'UCCE',
#   'race': 'Costa Rican'},
#  {'id': 241,
#   'first_name': 'Ianthe',
#   'last_name': 'Wise',
#   'email': 'iwise6o@tinyurl.com',
#   'gender': 'Female',
#   'skill': 'Clinical Psychology',
#   'race': 'Potawatomi'},
#  {'id': 242,
#   'first_name': 'Wesley',
#   'last_name': 'Iacobini',
#   'email': 'wiacobini6p@phpbb.com',
#   'gender': 'Male',
#   'skill': 'Early Childhood Education',
#   'race': 'Yuman'},
#  {'id': 243,
#   'first_name': 'Ber',
#   'last_name': 'Menilove',
#   'email': 'bmenilove6q@umn.edu',
#   'gender': 'Male',
#   'skill': 'VSAT',
#   'race': 'Chickasaw'},
#  {'id': 244,
#   'first_name': 'Arlan',
#   'last_name': 'Peplay',
#   'email': 'apeplay6r@mashable.com',
#   'gender': 'Male',
#   'skill': 'PC Anywhere',
#   'race': 'Salvadoran'},
#  {'id': 245,
#   'first_name': 'Frazer',
#   'last_name': 'Olman',
#   'email': 'folman6s@infoseek.co.jp',
#   'gender': 'Male',
#   'skill': 'Offshore Oil',
#   'race': "Tohono O'Odham"},
#  {'id': 246,
#   'first_name': 'Ezri',
#   'last_name': 'Hamm',
#   'email': 'ehamm6t@bravesites.com',
#   'gender': 'Male',
#   'skill': 'Job Coaching',
#   'race': 'Chippewa'},
#  {'id': 247,
#   'first_name': 'Corrie',
#   'last_name': 'Enbury',
#   'email': 'cenbury6u@timesonline.co.uk',
#   'gender': 'Male',
#   'skill': 'Real Estate Development',
#   'race': 'Uruguayan'},
#  {'id': 248,
#   'first_name': 'Rhonda',
#   'last_name': 'Grigore',
#   'email': 'rgrigore6v@wufoo.com',
#   'gender': 'Genderqueer',
#   'skill': 'TCLEOSE Instruction',
#   'race': 'Asian'},
#  {'id': 249,
#   'first_name': 'Tobias',
#   'last_name': 'Krolman',
#   'email': 'tkrolman6w@fotki.com',
#   'gender': 'Genderqueer',
#   'skill': 'ZK',
#   'race': 'Paraguayan'},
#  {'id': 250,
#   'first_name': 'Lavinie',
#   'last_name': 'State',
#   'email': 'lstate6x@furl.net',
#   'gender': 'Female',
#   'skill': 'HUET',
#   'race': 'Guamanian'},
#  {'id': 251,
#   'first_name': 'Eduard',
#   'last_name': 'Simmell',
#   'email': 'esimmell6y@nymag.com',
#   'gender': 'Male',
#   'skill': 'CSRs',
#   'race': 'Asian Indian'},
#  {'id': 252,
#   'first_name': 'Lek',
#   'last_name': 'Pymm',
#   'email': 'lpymm6z@surveymonkey.com',
#   'gender': 'Male',
#   'skill': 'Green Building',
#   'race': 'Alaska Native'},
#  {'id': 253,
#   'first_name': 'Lizzy',
#   'last_name': 'Boick',
#   'email': 'lboick70@sitemeter.com',
#   'gender': 'Female',
#   'skill': 'CQ',
#   'race': 'Yakama'},
#  {'id': 254,
#   'first_name': 'Shelby',
#   'last_name': 'Tulley',
#   'email': 'stulley71@cisco.com',
#   'gender': 'Male',
#   'skill': 'Nutrition Education',
#   'race': 'Panamanian'},
#  {'id': 255,
#   'first_name': 'Kathryn',
#   'last_name': 'Tatterton',
#   'email': 'ktatterton72@is.gd',
#   'gender': 'Female',
#   'skill': 'Groundwater',
#   'race': 'Hmong'},
#  {'id': 256,
#   'first_name': 'Cort',
#   'last_name': 'Kender',
#   'email': 'ckender73@live.com',
#   'gender': 'Male',
#   'skill': 'Slogans',
#   'race': 'Polynesian'},
#  {'id': 257,
#   'first_name': 'Maddalena',
#   'last_name': 'Guiot',
#   'email': 'mguiot74@illinois.edu',
#   'gender': 'Agender',
#   'skill': 'Land Development',
#   'race': 'Kiowa'},
#  {'id': 258,
#   'first_name': 'Gerry',
#   'last_name': 'Dikles',
#   'email': 'gdikles75@zimbio.com',
#   'gender': 'Male',
#   'skill': 'RDMA',
#   'race': 'Costa Rican'},
#  {'id': 259,
#   'first_name': 'Hilly',
#   'last_name': 'Kynvin',
#   'email': 'hkynvin76@weebly.com',
#   'gender': 'Male',
#   'skill': 'Microsoft Dynamics SL',
#   'race': 'Filipino'},
#  {'id': 260,
#   'first_name': 'Cassie',
#   'last_name': 'Georghiou',
#   'email': 'cgeorghiou77@gnu.org',
#   'gender': 'Male',
#   'skill': 'Swing',
#   'race': 'Ottawa'},
#  {'id': 261,
#   'first_name': 'Gustav',
#   'last_name': 'McMoyer',
#   'email': 'gmcmoyer78@oaic.gov.au',
#   'gender': 'Male',
#   'skill': 'XML-RPC',
#   'race': 'Seminole'},
#  {'id': 262,
#   'first_name': 'Charita',
#   'last_name': 'Bushell',
#   'email': 'cbushell79@meetup.com',
#   'gender': 'Female',
#   'skill': 'Acoustic Guitar',
#   'race': 'Sri Lankan'},
#  {'id': 263,
#   'first_name': 'Faith',
#   'last_name': 'Daens',
#   'email': 'fdaens7a@ca.gov',
#   'gender': 'Female',
#   'skill': 'Abstract Paintings',
#   'race': 'Guamanian'},
#  {'id': 264,
#   'first_name': 'Sigismund',
#   'last_name': 'McDowall',
#   'email': 'smcdowall7b@sciencedaily.com',
#   'gender': 'Agender',
#   'skill': 'Feature Writing',
#   'race': 'Panamanian'},
#  {'id': 265,
#   'first_name': 'Elaine',
#   'last_name': 'Pither',
#   'email': 'epither7c@joomla.org',
#   'gender': 'Female',
#   'skill': 'First Aid',
#   'race': 'Asian'},
#  {'id': 266,
#   'first_name': 'Netta',
#   'last_name': 'Hawksby',
#   'email': 'nhawksby7d@mozilla.com',
#   'gender': 'Female',
#   'skill': 'Blender',
#   'race': 'Venezuelan'},
#  {'id': 267,
#   'first_name': 'Matthus',
#   'last_name': 'De Benedictis',
#   'email': 'mdebenedictis7e@nydailynews.com',
#   'gender': 'Agender',
#   'skill': 'MDaemon',
#   'race': 'Native Hawaiian and Other Pacific Islander (NHPI)'},
#  {'id': 268,
#   'first_name': 'Valentina',
#   'last_name': 'Bortolutti',
#   'email': 'vbortolutti7f@omniture.com',
#   'gender': 'Polygender',
#   'skill': 'FHA',
#   'race': 'Kiowa'},
#  {'id': 269,
#   'first_name': 'Ofilia',
#   'last_name': 'Mullins',
#   'email': 'omullins7g@blogtalkradio.com',
#   'gender': 'Female',
#   'skill': 'Jet Ski',
#   'race': 'Delaware'},
#  {'id': 270,
#   'first_name': 'Linnell',
#   'last_name': 'Kendrew',
#   'email': 'lkendrew7h@feedburner.com',
#   'gender': 'Female',
#   'skill': 'DUI Defense',
#   'race': 'Indonesian'},
#  {'id': 271,
#   'first_name': 'Vivian',
#   'last_name': 'Devo',
#   'email': 'vdevo7i@sourceforge.net',
#   'gender': 'Female',
#   'skill': 'IBM Rational Tools',
#   'race': 'Paraguayan'},
#  {'id': 272,
#   'first_name': 'Melli',
#   'last_name': 'Chuck',
#   'email': 'mchuck7j@spiegel.de',
#   'gender': 'Female',
#   'skill': 'Mortgage Lending',
#   'race': 'Filipino'},
#  {'id': 273,
#   'first_name': 'Cosimo',
#   'last_name': 'MacDonagh',
#   'email': 'cmacdonagh7k@abc.net.au',
#   'gender': 'Non-binary',
#   'skill': 'Java Enterprise Edition',
#   'race': 'Filipino'},
#  {'id': 274,
#   'first_name': 'Clarice',
#   'last_name': 'De Freitas',
#   'email': 'cdefreitas7l@wix.com',
#   'gender': 'Female',
#   'skill': 'LPN',
#   'race': 'Cherokee'},
#  {'id': 275,
#   'first_name': 'Jermain',
#   'last_name': 'Hannen',
#   'email': 'jhannen7m@wufoo.com',
#   'gender': 'Male',
#   'skill': 'MM modules',
#   'race': 'Thai'},
#  {'id': 276,
#   'first_name': 'Myrvyn',
#   'last_name': 'Rother',
#   'email': 'mrother7n@comcast.net',
#   'gender': 'Male',
#   'skill': 'RHEL',
#   'race': 'Native Hawaiian'},
#  {'id': 277,
#   'first_name': 'Tybie',
#   'last_name': 'Coppock.',
#   'email': 'tcoppock7o@youku.com',
#   'gender': 'Female',
#   'skill': 'Military Training',
#   'race': 'Navajo'},
#  {'id': 278,
#   'first_name': 'Loree',
#   'last_name': 'Bowkley',
#   'email': 'lbowkley7p@live.com',
#   'gender': 'Female',
# ...
#   'gender': 'Female',
#   'skill': 'RPOs',
#   'race': 'Iroquois'},
#  {'id': 909,
#   'first_name': 'Libbi',
#   'last_name': 'Salway',
#   'email': 'lsalwayp8@epa.gov',
#   'gender': 'Female',
#   'skill': 'CPLD',
#   'race': 'South American'},
#  {'id': 910,
#   'first_name': 'Bonni',
#   'last_name': 'Twining',
#   'email': 'btwiningp9@va.gov',
#   'gender': 'Female',
#   'skill': 'Townhomes',
#   'race': 'Paraguayan'},
#  {'id': 911,
#   'first_name': 'Liza',
#   'last_name': 'Sexon',
#   'email': 'lsexonpa@eepurl.com',
#   'gender': 'Female',
#   'skill': 'Wicklander-Zulawski Interview &amp; Interrogation',
#   'race': 'Cuban'},
#  {'id': 912,
#   'first_name': 'Vergil',
#   'last_name': 'Broomer',
#   'email': 'vbroomerpb@t-online.de',
#   'gender': 'Male',
#   'skill': 'French',
#   'race': 'Cherokee'},
#  {'id': 913,
#   'first_name': 'Yasmeen',
#   'last_name': 'MacGraith',
#   'email': 'ymacgraithpc@addtoany.com',
#   'gender': 'Female',
#   'skill': 'Cross-functional Coordination',
#   'race': 'American Indian'},
#  {'id': 914,
#   'first_name': 'Rodrique',
#   'last_name': 'Doring',
#   'email': 'rdoringpd@zdnet.com',
#   'gender': 'Male',
#   'skill': 'Light Rail',
#   'race': 'Indonesian'},
#  {'id': 915,
#   'first_name': 'Lancelot',
#   'last_name': 'Hansana',
#   'email': 'lhansanape@loc.gov',
#   'gender': 'Male',
#   'skill': 'JVs',
#   'race': 'Menominee'},
#  {'id': 916,
#   'first_name': 'Myrvyn',
#   'last_name': 'Danielot',
#   'email': 'mdanielotpf@java.com',
#   'gender': 'Male',
#   'skill': 'VSA',
#   'race': 'Shoshone'},
#  {'id': 917,
#   'first_name': 'Rickie',
#   'last_name': 'Brasier',
#   'email': 'rbrasierpg@reference.com',
#   'gender': 'Female',
#   'skill': 'MMIC',
#   'race': 'Thai'},
#  {'id': 918,
#   'first_name': 'Gianina',
#   'last_name': 'Fardy',
#   'email': 'gfardyph@elpais.com',
#   'gender': 'Female',
#   'skill': 'Trimble GPS',
#   'race': 'Filipino'},
#  {'id': 919,
#   'first_name': 'Maurine',
#   'last_name': 'Gregoretti',
#   'email': 'mgregorettipi@mail.ru',
#   'gender': 'Female',
#   'skill': 'xPON',
#   'race': 'Colville'},
#  {'id': 920,
#   'first_name': 'Currie',
#   'last_name': 'Anten',
#   'email': 'cantenpj@fastcompany.com',
#   'gender': 'Male',
#   'skill': 'PCP',
#   'race': 'Guamanian'},
#  {'id': 921,
#   'first_name': 'Toni',
#   'last_name': 'MacPharlain',
#   'email': 'tmacpharlainpk@parallels.com',
#   'gender': 'Female',
#   'skill': 'VPython',
#   'race': 'Costa Rican'},
#  {'id': 922,
#   'first_name': 'Herrick',
#   'last_name': 'Wornum',
#   'email': 'hwornumpl@scribd.com',
#   'gender': 'Male',
#   'skill': 'Change Orders',
#   'race': 'Alaskan Athabascan'},
#  {'id': 923,
#   'first_name': 'Basia',
#   'last_name': 'Strethill',
#   'email': 'bstrethillpm@ox.ac.uk',
#   'gender': 'Female',
#   'skill': 'DHCP',
#   'race': 'Yuman'},
#  {'id': 924,
#   'first_name': 'Carson',
#   'last_name': 'Sowrey',
#   'email': 'csowreypn@bandcamp.com',
#   'gender': 'Non-binary',
#   'skill': 'VLSI',
#   'race': 'Nicaraguan'},
#  {'id': 925,
#   'first_name': 'Eduino',
#   'last_name': 'Budleigh',
#   'email': 'ebudleighpo@arizona.edu',
#   'gender': 'Male',
#   'skill': 'Therapeutic Areas',
#   'race': 'Venezuelan'},
#  {'id': 926,
#   'first_name': 'Emile',
#   'last_name': 'Imlaw',
#   'email': 'eimlawpp@google.co.uk',
#   'gender': 'Male',
#   'skill': 'TPU',
#   'race': 'Polynesian'},
#  {'id': 927,
#   'first_name': 'Travus',
#   'last_name': 'Tomet',
#   'email': 'ttometpq@indiatimes.com',
#   'gender': 'Male',
#   'skill': 'DNS',
#   'race': 'Guamanian'},
#  {'id': 928,
#   'first_name': 'Liv',
#   'last_name': 'Uttermare',
#   'email': 'luttermarepr@nih.gov',
#   'gender': 'Female',
#   'skill': 'TWS',
#   'race': 'Cherokee'},
#  {'id': 929,
#   'first_name': 'Trumaine',
#   'last_name': 'Larn',
#   'email': 'tlarnps@icq.com',
#   'gender': 'Male',
#   'skill': 'Pain Management',
#   'race': 'Taiwanese'},
#  {'id': 930,
#   'first_name': 'Saunders',
#   'last_name': 'Giorgi',
#   'email': 'sgiorgipt@cdc.gov',
#   'gender': 'Male',
#   'skill': 'PMM',
#   'race': 'Apache'},
#  {'id': 931,
#   'first_name': 'Vincent',
#   'last_name': 'Antrag',
#   'email': 'vantragpu@so-net.ne.jp',
#   'gender': 'Male',
#   'skill': 'MDOP',
#   'race': 'Potawatomi'},
#  {'id': 932,
#   'first_name': 'Erminia',
#   'last_name': 'Hubberstey',
#   'email': 'ehubbersteypv@drupal.org',
#   'gender': 'Female',
#   'skill': 'HP EVA',
#   'race': 'Chickasaw'},
#  {'id': 933,
#   'first_name': 'Myrwyn',
#   'last_name': 'Lefeuvre',
#   'email': 'mlefeuvrepw@utexas.edu',
#   'gender': 'Male',
#   'skill': 'White Papers',
#   'race': 'Navajo'},
#  {'id': 934,
#   'first_name': 'Andromache',
#   'last_name': 'Macias',
#   'email': 'amaciaspx@archive.org',
#   'gender': 'Female',
#   'skill': 'Offset Printing',
#   'race': 'Comanche'},
#  {'id': 935,
#   'first_name': 'Norby',
#   'last_name': 'Felix',
#   'email': 'nfelixpy@mysql.com',
#   'gender': 'Male',
#   'skill': 'FMCSR',
#   'race': 'Houma'},
#  {'id': 936,
#   'first_name': 'Serena',
#   'last_name': 'Smeal',
#   'email': 'ssmealpz@issuu.com',
#   'gender': 'Female',
#   'skill': 'Healthy Eating',
#   'race': 'Blackfeet'},
#  {'id': 937,
#   'first_name': 'Gustavus',
#   'last_name': 'Duffin',
#   'email': 'gduffinq0@seattletimes.com',
#   'gender': 'Male',
#   'skill': 'Kenan FX',
#   'race': 'Alaska Native'},
#  {'id': 938,
#   'first_name': 'Marlo',
#   'last_name': 'McGinnell',
#   'email': 'mmcginnellq1@google.ca',
#   'gender': 'Female',
#   'skill': 'Avid Xpress',
#   'race': 'Native Hawaiian'},
#  {'id': 939,
#   'first_name': 'Donny',
#   'last_name': 'Kingsman',
#   'email': 'dkingsmanq2@alibaba.com',
#   'gender': 'Male',
#   'skill': 'KOL Management',
#   'race': 'Cherokee'},
#  {'id': 940,
#   'first_name': 'Farr',
#   'last_name': 'Klaesson',
#   'email': 'fklaessonq3@barnesandnoble.com',
#   'gender': 'Male',
#   'skill': 'Notary Public',
#   'race': 'Cherokee'},
#  {'id': 941,
#   'first_name': 'Ado',
#   'last_name': 'Tollerton',
#   'email': 'atollertonq4@telegraph.co.uk',
#   'gender': 'Male',
#   'skill': 'GNU Octave',
#   'race': 'Lumbee'},
#  {'id': 942,
#   'first_name': 'Nixie',
#   'last_name': 'Todarello',
#   'email': 'ntodarelloq5@ask.com',
#   'gender': 'Female',
#   'skill': 'Epigenetics',
#   'race': 'Ute'},
#  {'id': 943,
#   'first_name': 'Domeniga',
#   'last_name': 'Golling',
#   'email': 'dgollingq6@ebay.co.uk',
#   'gender': 'Polygender',
#   'skill': 'European Politics',
#   'race': 'Menominee'},
#  {'id': 944,
#   'first_name': 'Juieta',
#   'last_name': 'Skeermer',
#   'email': 'jskeermerq7@constantcontact.com',
#   'gender': 'Female',
#   'skill': 'Berkeley DB',
#   'race': 'Pakistani'},
#  {'id': 945,
#   'first_name': 'Corrinne',
#   'last_name': 'Jeeves',
#   'email': 'cjeevesq8@dailymotion.com',
#   'gender': 'Female',
#   'skill': 'Union',
#   'race': 'Black or African American'},
#  {'id': 946,
#   'first_name': 'Dulcy',
#   'last_name': 'Dowderswell',
#   'email': 'ddowderswellq9@unesco.org',
#   'gender': 'Female',
#   'skill': 'ABAP Web Dynpro',
#   'race': 'Black or African American'},
#  {'id': 947,
#   'first_name': 'Aubine',
#   'last_name': 'Blune',
#   'email': 'abluneqa@census.gov',
#   'gender': 'Female',
#   'skill': 'CGI',
#   'race': 'Lumbee'},
#  {'id': 948,
#   'first_name': 'Tim',
#   'last_name': 'Halbard',
#   'email': 'thalbardqb@histats.com',
#   'gender': 'Agender',
#   'skill': 'HMC',
#   'race': 'Yaqui'},
#  {'id': 949,
#   'first_name': 'Davidson',
#   'last_name': 'Accombe',
#   'email': 'daccombeqc@cargocollective.com',
#   'gender': 'Male',
#   'skill': 'ABS',
#   'race': 'Paiute'},
#  {'id': 950,
#   'first_name': 'Rosalyn',
#   'last_name': 'Mayward',
#   'email': 'rmaywardqd@cargocollective.com',
#   'gender': 'Female',
#   'skill': 'MySQLi',
#   'race': 'Sioux'},
#  {'id': 951,
#   'first_name': 'Cory',
#   'last_name': 'Bartholin',
#   'email': 'cbartholinqe@sohu.com',
#   'gender': 'Male',
#   'skill': 'InDesign',
#   'race': 'Indonesian'},
#  {'id': 952,
#   'first_name': 'Hubie',
#   'last_name': 'Bevar',
#   'email': 'hbevarqf@desdev.cn',
#   'gender': 'Male',
#   'skill': 'Multilingual',
#   'race': 'Creek'},
#  {'id': 953,
#   'first_name': 'Giulio',
#   'last_name': 'McRobb',
#   'email': 'gmcrobbqg@hugedomains.com',
#   'gender': 'Male',
#   'skill': 'Outerwear',
#   'race': 'Korean'},
#  {'id': 954,
#   'first_name': 'Devonne',
#   'last_name': 'Behnke',
#   'email': 'dbehnkeqh@artisteer.com',
#   'gender': 'Genderfluid',
#   'skill': 'Process Efficiency',
#   'race': 'Houma'},
#  {'id': 955,
#   'first_name': 'Robyn',
#   'last_name': 'Oldcroft',
#   'email': 'roldcroftqi@hibu.com',
#   'gender': 'Female',
#   'skill': 'Gastroenterology',
#   'race': 'Chickasaw'},
#  {'id': 956,
#   'first_name': 'Lilia',
#   'last_name': 'Crispin',
#   'email': 'lcrispinqj@shareasale.com',
#   'gender': 'Female',
#   'skill': 'iPad Development',
#   'race': 'Mexican'},
#  {'id': 957,
#   'first_name': 'Huberto',
#   'last_name': 'Stewartson',
#   'email': 'hstewartsonqk@newyorker.com',
#   'gender': 'Male',
#   'skill': 'Glamour',
#   'race': 'Asian Indian'},
#  {'id': 958,
#   'first_name': 'Devin',
#   'last_name': 'Bettles',
#   'email': 'dbettlesql@nih.gov',
#   'gender': 'Female',
#   'skill': 'Gynecology',
#   'race': 'Hmong'},
#  {'id': 959,
#   'first_name': 'Chane',
#   'last_name': 'Campanelli',
#   'email': 'ccampanelliqm@salon.com',
#   'gender': 'Male',
#   'skill': 'DNA fingerprinting',
#   'race': 'Pima'},
#  {'id': 960,
#   'first_name': 'Stu',
#   'last_name': 'Capeloff',
#   'email': 'scapeloffqn@telegraph.co.uk',
#   'gender': 'Male',
#   'skill': 'Child Development',
#   'race': 'Argentinian'},
#  {'id': 961,
#   'first_name': 'Doralynne',
#   'last_name': 'Grandham',
#   'email': 'dgrandhamqo@jalbum.net',
#   'gender': 'Female',
#   'skill': 'Ignatian Spirituality',
#   'race': 'Bangladeshi'},
#  {'id': 962,
#   'first_name': 'Jethro',
#   'last_name': 'Maddams',
#   'email': 'jmaddamsqp@w3.org',
#   'gender': 'Male',
#   'skill': 'TyMetrix',
#   'race': 'Iroquois'},
#  {'id': 963,
#   'first_name': 'Nelle',
#   'last_name': 'Stockney',
#   'email': 'nstockneyqq@topsy.com',
#   'gender': 'Non-binary',
#   'skill': 'Water Features',
#   'race': 'Korean'},
#  {'id': 964,
#   'first_name': 'Aigneis',
#   'last_name': 'Swales',
#   'email': 'aswalesqr@cdc.gov',
#   'gender': 'Female',
#   'skill': 'Apartments',
#   'race': 'Creek'},
#  {'id': 965,
#   'first_name': 'Beatrisa',
#   'last_name': 'Grinvalds',
#   'email': 'bgrinvaldsqs@google.com.br',
#   'gender': 'Female',
#   'skill': 'DVB-RCS',
#   'race': 'American Indian'},
#  {'id': 966,
#   'first_name': 'Dulcine',
#   'last_name': 'Tiler',
#   'email': 'dtilerqt@gizmodo.com',
#   'gender': 'Female',
#   'skill': 'Play by Play',
#   'race': 'Pueblo'},
#  {'id': 967,
#   'first_name': 'Ginny',
#   'last_name': 'Benjafield',
#   'email': 'gbenjafieldqu@disqus.com',
#   'gender': 'Non-binary',
#   'skill': 'Solid Oxide Fuel Cells',
#   'race': 'Venezuelan'},
#  {'id': 968,
#   'first_name': 'Margo',
#   'last_name': 'Berry',
#   'email': 'mberryqv@networksolutions.com',
#   'gender': 'Female',
#   'skill': 'Long Distance Running',
#   'race': 'Seminole'},
#  {'id': 969,
#   'first_name': 'Allard',
#   'last_name': 'Lammenga',
#   'email': 'alammengaqw@soup.io',
#   'gender': 'Male',
#   'skill': 'Home Staging',
#   'race': 'Guatemalan'},
#  {'id': 970,
#   'first_name': 'Martica',
#   'last_name': 'Buckett',
#   'email': 'mbuckettqx@nymag.com',
#   'gender': 'Bigender',
#   'skill': 'MCH',
#   'race': 'Lumbee'},
#  {'id': 971,
#   'first_name': 'Cris',
#   'last_name': 'Caldow',
#   'email': 'ccaldowqy@t.co',
#   'gender': 'Female',
#   'skill': 'Overseas Experience',
#   'race': 'American Indian and Alaska Native (AIAN)'},
#  {'id': 972,
#   'first_name': 'Emmeline',
#   'last_name': 'Nary',
#   'email': 'enaryqz@studiopress.com',
#   'gender': 'Female',
#   'skill': 'WSIB',
#   'race': 'Osage'},
#  {'id': 973,
#   'first_name': 'Maisey',
#   'last_name': 'Austen',
#   'email': 'maustenr0@lycos.com',
#   'gender': 'Female',
#   'skill': 'GNS3',
#   'race': 'Venezuelan'},
#  {'id': 974,
#   'first_name': 'Marwin',
#   'last_name': 'Helgass',
#   'email': 'mhelgassr1@google.es',
#   'gender': 'Male',
#   'skill': 'UK Law',
#   'race': 'Cherokee'},
#  {'id': 975,
#   'first_name': 'Hersh',
#   'last_name': 'Ragot',
#   'email': 'hragotr2@virginia.edu',
#   'gender': 'Male',
#   'skill': 'DV Camera Operator',
#   'race': 'Nicaraguan'},
#  {'id': 976,
#   'first_name': 'Reggie',
#   'last_name': 'Hanscome',
#   'email': 'rhanscomer3@google.fr',
#   'gender': 'Male',
#   'skill': 'MRB',
#   'race': 'Creek'},
#  {'id': 977,
#   'first_name': 'Hermann',
#   'last_name': 'Draisey',
#   'email': 'hdraiseyr4@ask.com',
#   'gender': 'Male',
#   'skill': 'MPIO',
#   'race': 'White'},
#  {'id': 978,
#   'first_name': 'Hammad',
#   'last_name': 'Rickets',
#   'email': 'hricketsr5@liveinternet.ru',
#   'gender': 'Male',
#   'skill': 'Gifts',
#   'race': 'Native Hawaiian'},
#  {'id': 979,
#   'first_name': 'Harlen',
#   'last_name': 'Waldram',
#   'email': 'hwaldramr6@hexun.com',
#   'gender': 'Male',
#   'skill': 'AV',
#   'race': "Tohono O'Odham"},
#  {'id': 980,
#   'first_name': 'Emmi',
#   'last_name': 'Frodsham',
#   'email': 'efrodshamr7@sun.com',
#   'gender': 'Female',
#   'skill': 'JIRA',
#   'race': 'Costa Rican'},
#  {'id': 981,
#   'first_name': 'Teodor',
#   'last_name': 'Brok',
#   'email': 'tbrokr8@thetimes.co.uk',
#   'gender': 'Male',
#   'skill': 'FNMA',
#   'race': 'Osage'},
#  {'id': 982,
#   'first_name': 'Farlee',
#   'last_name': 'Basini-Gazzi',
#   'email': 'fbasinigazzir9@eventbrite.com',
#   'gender': 'Male',
#   'skill': 'Outplacement',
#   'race': 'Micronesian'},
#  {'id': 983,
#   'first_name': 'Terencio',
#   'last_name': 'Lingfoot',
#   'email': 'tlingfootra@oakley.com',
#   'gender': 'Male',
#   'skill': 'Waxing',
#   'race': 'Kiowa'},
#  {'id': 984,
#   'first_name': 'Cristine',
#   'last_name': 'Kembley',
#   'email': 'ckembleyrb@studiopress.com',
#   'gender': 'Female',
#   'skill': 'Islamic Finance',
#   'race': 'Ottawa'},
#  {'id': 985,
#   'first_name': 'Babb',
#   'last_name': 'MacAindreis',
#   'email': 'bmacaindreisrc@wikipedia.org',
#   'gender': 'Bigender',
#   'skill': 'SFX Editing',
#   'race': 'Navajo'},
#  {'id': 986,
#   'first_name': 'Ashlie',
#   'last_name': 'Mitchenson',
#   'email': 'amitchensonrd@craigslist.org',
#   'gender': 'Female',
#   'skill': 'Uzbek',
#   'race': 'Polynesian'},
#  {'id': 987,
#   'first_name': 'Killie',
#   'last_name': 'Maps',
#   'email': 'kmapsre@ed.gov',
#   'gender': 'Male',
#   'skill': 'Procurement',
#   'race': 'Malaysian'},
#  {'id': 988,
#   'first_name': 'Dillie',
#   'last_name': 'Yedall',
#   'email': 'dyedallrf@prnewswire.com',
#   'gender': 'Male',
#   'skill': 'OTP',
#   'race': 'Bangladeshi'},
#  {'id': 989,
#   'first_name': 'Yoshi',
#   'last_name': 'Meeke',
#   'email': 'ymeekerg@cocolog-nifty.com',
#   'gender': 'Bigender',
#   'skill': 'Mobile Applications',
#   'race': 'Native Hawaiian'},
#  {'id': 990,
#   'first_name': 'Tobye',
#   'last_name': 'Gley',
#   'email': 'tgleyrh@kickstarter.com',
#   'gender': 'Female',
#   'skill': 'Project Estimation',
#   'race': 'Chinese'},
#  {'id': 991,
#   'first_name': 'Avigdor',
#   'last_name': 'Elmer',
#   'email': 'aelmerri@apache.org',
#   'gender': 'Male',
#   'skill': 'Ion Chromatography',
#   'race': 'Yuman'},
#  {'id': 992,
#   'first_name': 'Symon',
#   'last_name': 'Blackborn',
#   'email': 'sblackbornrj@symantec.com',
#   'gender': 'Male',
#   'skill': 'IP CCTV',
#   'race': 'Apache'},
#  {'id': 993,
#   'first_name': 'Marga',
#   'last_name': 'Botterman',
#   'email': 'mbottermanrk@blogtalkradio.com',
#   'gender': 'Female',
#   'skill': 'HtmlUnit',
#   'race': 'Chinese'},
#  {'id': 994,
#   'first_name': 'Ethelyn',
#   'last_name': 'Tomik',
#   'email': 'etomikrl@japanpost.jp',
#   'gender': 'Female',
#   'skill': 'gSOAP',
#   'race': 'Panamanian'},
#  {'id': 995,
#   'first_name': 'Sissy',
#   'last_name': 'Bonhill',
#   'email': 'sbonhillrm@umich.edu',
#   'gender': 'Female',
#   'skill': 'IBM Websphere Commerce',
#   'race': 'Black or African American'},
#  {'id': 996,
#   'first_name': 'Zara',
#   'last_name': 'Seamer',
#   'email': 'zseamerrn@soundcloud.com',
#   'gender': 'Female',
#   'skill': 'Slickline',
#   'race': 'Yuman'},
#  {'id': 997,
#   'first_name': 'Pembroke',
#   'last_name': 'Herion',
#   'email': 'pherionro@zdnet.com',
#   'gender': 'Male',
#   'skill': 'ATLS',
#   'race': 'Puerto Rican'},
#  {'id': 998,
#   'first_name': 'Marthena',
#   'last_name': 'Jagson',
#   'email': 'mjagsonrp@themeforest.net',
#   'gender': 'Female',
#   'skill': 'RTOS',
#   'race': 'Chickasaw'},
#  {'id': 999,
#   'first_name': 'Terencio',
#   'last_name': 'Annetts',
#   'email': 'tannettsrq@prlog.org',
#   'gender': 'Male',
#   'skill': 'OSHA 30-Hour',
#   'race': 'Yakama'},
#  {'id': 1000,
#   'first_name': 'Manya',
#   'last_name': 'Ziebart',
#   'email': 'mziebartrr@house.gov',
#   'gender': 'Female',
#   'skill': 'FPA',
#   'race': 'Central American'}]

# %% [markdown]
# **Select Data with Condition**

# %%
table.select('*').eq('race','Filipino').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 51, 'first_name': 'Gillie', 'last_name': 'Gethings', 'email': 'ggethings1e@boston.com', 'gender': 'Female', 'skill': 'VPLS', 'race': 'Filipino'}, {'id': 78, 'first_name': 'Norma', 'last_name': 'Metcalf', 'email': 'nmetcalf25@123-reg.co.uk', 'gender': 'Female', 'skill': 'Tiles', 'race': 'Filipino'}, {'id': 87, 'first_name': 'Hanna', 'last_name': 'Fishlee', 'email': 'hfishlee2e@hatena.ne.jp', 'gender': 'Female', 'skill': 'Updos', 'race': 'Filipino'}, {'id': 217, 'first_name': 'Babb', 'last_name': 'Gladstone', 'email': 'bgladstone60@unicef.org', 'gender': 'Female', 'skill': 'Start-up Ventures', 'race': 'Filipino'}, {'id': 259, 'first_name': 'Hilly', 'last_name': 'Kynvin', 'email': 'hkynvin76@weebly.com', 'gender': 'Male', 'skill': 'Microsoft Dynamics SL', 'race': 'Filipino'}, {'id': 272, 'first_name': 'Melli', 'last_name': 'Chuck', 'email': 'mchuck7j@spiegel.de', 'gender': 'Female', 'skill': 'Mortgage Lending', 'race': 'Filipino'}, {'id': 273, 'first_name': 'Cosimo', 'last_name': 'MacDonagh', 'email': 'cmacdonagh7k@abc.net.au', 'gender': 'Non-binary', 'skill': 'Java Enterprise Edition', 'race': 'Filipino'}, {'id': 340, 'first_name': 'Benjie', 'last_name': 'Oxby', 'email': 'boxby9f@storify.com', 'gender': 'Male', 'skill': 'WCB', 'race': 'Filipino'}, {'id': 345, 'first_name': 'Cherey', 'last_name': 'Farlambe', 'email': 'cfarlambe9k@quantcast.com', 'gender': 'Female', 'skill': 'Play Therapy', 'race': 'Filipino'}, {'id': 634, 'first_name': 'Raleigh', 'last_name': 'Happert', 'email': 'rhapperthl@vistaprint.com', 'gender': 'Male', 'skill': 'Red Hat Linux', 'race': 'Filipino'}, {'id': 636, 'first_name': 'Ashely', 'last_name': 'Macilhench', 'email': 'amacilhenchhn@ning.com', 'gender': 'Female', 'skill': 'DL1', 'race': 'Filipino'}, {'id': 651, 'first_name': 'Leonhard', 'last_name': 'Berzen', 'email': 'lberzeni2@domainmarket.com', 'gender': 'Genderqueer', 'skill': 'SNF', 'race': 'Filipino'}, {'id': 918, 'first_name': 'Gianina', 'last_name': 'Fardy', 'email': 'gfardyph@elpais.com', 'gender': 'Female', 'skill': 'Trimble GPS', 'race': 'Filipino'}, {'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}], count=None)

# %% [markdown]
# **Convert Structured Data as DataFrame Object**

# %%
fil_df = pd.DataFrame(table.select('*').eq('race','Filipino').execute().dict()['data'])
fil_df.head()
# Out:
#     id first_name  last_name                     email  gender  \
# 0   51     Gillie   Gethings    ggethings1e@boston.com  Female
# 1   78      Norma    Metcalf  nmetcalf25@123-reg.co.uk  Female
# 2   87      Hanna    Fishlee   hfishlee2e@hatena.ne.jp  Female
# 3  217       Babb  Gladstone   bgladstone60@unicef.org  Female
# 4  259      Hilly     Kynvin      hkynvin76@weebly.com    Male
#
#                    skill      race
# 0                   VPLS  Filipino
# 1                  Tiles  Filipino
# 2                  Updos  Filipino
# 3      Start-up Ventures  Filipino
# 4  Microsoft Dynamics SL  Filipino

# %% [markdown]
# **Insert Data**

# %%
table.insert({
    'id':1001,
    'first_name':'Jhun Brian',
    'last_name':'Matic',
    'email':'brian@hotmail.com',
    'gender':'Male',
    'skill':'Magpanggap',
    'race':'Filipino'
}).execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Matic', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}], count=None)

# %% [markdown]
# *Query Newly Inserted Instance*

# %%
table.select('first_name').eq('first_name', 'Jhun Brian').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'first_name': 'Jhun Brian'}, {'first_name': 'Jhun Brian'}], count=None)

# %% [markdown]
# **Update Data**

# %%
table.update({
    'last_name':'Andam'
}).eq('id', '1001').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}, {'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}], count=None)

# %% [markdown]
# *Query Newly Updated Instance*

# %%
table.select('*').eq('first_name', 'Jhun Brian').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}, {'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}], count=None)

# %% [markdown]
# **Delete Data**

# %%
table.delete().eq('id','1001').execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}, {'id': 1001, 'first_name': 'Jhun Brian', 'last_name': 'Andam', 'email': 'brian@hotmail.com', 'gender': 'Male', 'skill': 'Magpanggap', 'race': 'Filipino'}], count=None)

# %%
table.select('*').eq('first_name', 'Jhun Brian').execute()
# Out:
# APIResponse[~_ReturnT](data=[], count=None)
